# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Transactions_1 = [['eggs', 'bacon', 'soup'],
                ['eggs', 'bacon', 'apple'],
                ['soup', 'bacon', 'banana']]
Transactions_1
# Out:
# [['eggs', 'bacon', 'soup'],
#  ['eggs', 'bacon', 'apple'],
#  ['soup', 'bacon', 'banana']]

# %%
print('support of {egg, soup}:', 1/3,'conf of {egg, soup}:',1/2,'lift of {egg, soup}:',(1/(2))/(2/3))
# Out:
# support of {egg, soup}: 0.3333333333333333 conf of {egg, soup}: 0.5 lift of {egg, soup}: 0.75

# %% [raw]
#  RelationRecord(items=frozenset({'soup', 'eggs'}), support=0.3333333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'soup', 'eggs'}), confidence=0.3333333333333333, lift=1.0), OrderedStatistic(items_base=frozenset({'eggs'}), items_add=frozenset({'soup'}), confidence=0.5, lift=0.75), OrderedStatistic(items_base=frozenset({'soup'}), items_add=frozenset({'eggs'}), confidence=0.5, lift=0.75)]),

# %%
from apriori import apriori
rules = apriori(Transactions_1, min_support = 0.2, min_confidence = 0.5, min_lift =.7) 
# making rules for two items
# Visualising the results
results = list(rules)
results
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-bf2889464d23> in <module>
# ----> 1 from apriori import apriori
#       2 rules = apriori(Transactions_1, min_support = 0.2, min_confidence = 0.5, min_lift =.7)
#       3 # making rules for two items
#       4 # Visualising the results
#       5 results = list(rules)
#
# ~\Documents\Python Scripts\apriori\apriori.py in <module>
#      13
#      14 # Training Apriori on the dataset
# ---> 15 from apyori import apriori
#      16 rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)
#      17
#
# ModuleNotFoundError: No module named 'apyori'

# %%
dataset = pd.read_csv("Market_Basket_Optimisation.csv",header = None) # dataset with no title so header = none
ds=dataset.shape
ds
# Out:
# (7501, 20)

# %%
dataset
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %% [markdown]
# Min_Support
# purchased 3 times a day for 7 days = 3*7 = 21
# total transaction = 7500
# Support = 21/7500 = .0028
#
# Confidence
#
# Lift
# High Lift good rules
#
# *Varies with different buissness problems and do trial and error *

# %%
transactions = []
for i in range(0, ds[0]):
    transactions.append(tuple([str(dataset.values[i,j]) for j in range(0, 3)]))
    
#we have to structure like this because Apriori algo  expecting this as input

# %%
rules = apriori(transactions_1, min_support = 0.002, min_confidence = 0.001, min_lift =0) 
# making rules for two items
# Visualising the results
results = list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'almonds'}), support=0.020397280362618318, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'almonds'}), confidence=0.020397280362618318, lift=1.0)]),
#  RelationRecord(items=frozenset({'antioxydant juice'}), support=0.008932142381015865, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'antioxydant juice'}), confidence=0.008932142381015865, lift=1.0)]),
#  RelationRecord(items=frozenset({'asparagus'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'asparagus'}), confidence=0.004666044527396347, lift=1.0)]),
#  RelationRecord(items=frozenset({'avocado'}), support=0.03332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset(), items_add=frozenset({'avocado'}), confidence=0.03332888948140248, lift=1.0)]),
# ...

# %% [markdown]
# # -------------End--------------

# %% [markdown]
# # Another approach

# %%
from efficient_apriori import apriori
Transactions = [('eggs', 'bacon', 'soup'),
                ('eggs', 'bacon', 'apple'),
                ('soup', 'bacon', 'banana')]
Itemsets, Rules = apriori(Transactions, min_support=.01,  min_confidence=.01)

# %%
Rules_rhs = filter(lambda Rule: len(Rule.lhs) == 1 and len(Rule.rhs) == 2, Rules)
#rules_rhs
for Rule in Rules_rhs:
     print(Rule) 
#print('support of {egg, soup}:', 1/3,'conf of {egg, soup}:',1/2,'lift of {egg, soup}:',(1/(2))/(2/3))
# Out:
# {soup} -> {bacon, eggs} (conf: 0.500, supp: 0.333, lift: 0.750, conv: 0.667)
# {eggs} -> {bacon, soup} (conf: 0.500, supp: 0.333, lift: 0.750, conv: 0.667)
# {bacon} -> {eggs, soup} (conf: 0.333, supp: 0.333, lift: 1.000, conv: 1.000)
# {eggs} -> {apple, bacon} (conf: 0.500, supp: 0.333, lift: 1.500, conv: 1.333)
# {bacon} -> {apple, eggs} (conf: 0.333, supp: 0.333, lift: 1.000, conv: 1.000)
# {apple} -> {bacon, eggs} (conf: 1.000, supp: 0.333, lift: 1.500, conv: 333333333.333)
# {soup} -> {bacon, banana} (conf: 0.500, supp: 0.333, lift: 1.500, conv: 1.333)
# {banana} -> {bacon, soup} (conf: 1.000, supp: 0.333, lift: 1.500, conv: 333333333.333)
# {bacon} -> {banana, soup} (conf: 0.333, supp: 0.333, lift: 1.000, conv: 1.000)
